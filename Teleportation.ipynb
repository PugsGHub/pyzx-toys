# %% [markdown]
# # Teleportation protocol

# %%
import sys; sys.path.insert(0, '..')
import random
import pyzx as zx
from fractions import Fraction
from ipywidgets import widgets
from IPython.display import display, Markdown
from pyzx.simplify import clifford_iter

# %%
#Setting random measurement outcomes
b_1 = random.randint(0, 1)
b_2 = random.randint(0, 1)

# %%
#Initializing the states
b_1 = 1 #Phase for a
b_2 = 0 #Phase for b

# %%
#Initializing arbitrary states
b_1 = random.randint(0, 1) #Phase for a 
b_2 = random.randint(0, 1) #Phase for b

# %%
teleportation_circuit = zx.Graph()

t_i_1 = teleportation_circuit.add_vertex(0, 0, 0, Fraction(0))

t_a = teleportation_circuit.add_vertex(2, 0, 1, Fraction(0))
t_b = teleportation_circuit.add_vertex(2, 0, 5, Fraction(b_1))

#Qubit 2
t_c = teleportation_circuit.add_vertex(1, 1, 1, Fraction(0))
t_d = teleportation_circuit.add_vertex(1, 1, 2, Fraction(1/2))
t_e = teleportation_circuit.add_vertex(2, 1, 3, Fraction(1/2))
t_f = teleportation_circuit.add_vertex(1, 1, 4, Fraction(1/2))
t_g = teleportation_circuit.add_vertex(2, 1, 5, Fraction(b_2))

#Qubit 3
t_h = teleportation_circuit.add_vertex(1, 2, 5, Fraction(b_2))
t_i = teleportation_circuit.add_vertex(2, 2, 6, Fraction(b_1))

t_o_1 = teleportation_circuit.add_vertex(0, 2, 7, Fraction(0))

teleportation_circuit.add_edges([(t_i_1, t_a),(t_a, t_b), (t_a,t_c), (t_c,t_d), (t_d,t_e), (t_e,t_f), (t_f,t_g), (t_c, t_h), (t_h, t_i), (t_i, t_o_1)])

zx.draw_matplotlib(teleportation_circuit, labels=True)

# %%
g = teleportation_circuit.copy()
zx.clifford_simp(g)  # simplifies the diagram
g.normalize()  # makes it more presentable
zx.draw_matplotlib(g)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23048/1908905756.py in <module>
# ----> 1 zx.clifford_simp(g)  # simplifies the diagram
#       2 g.normalize()  # makes it more presentable
#       3 zx.draw_matplotlib(g)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pyzx\simplify.py in clifford_simp(g, quiet, stats)
#     163     i = 0
#     164     while True:
# --> 165         i += interior_clifford_simp(g, quiet=quiet, stats=stats)
#     166         i2 = pivot_boundary_simp(g, quiet=quiet, stats=stats)
#     167         if i2 == 0:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pyzx\simplify.py in interior_clifford_simp(g, quiet, stats)
#     146     """Keeps doing the simplifications ``id_simp``, ``spider_simp``,
#     147     ``pivot_simp`` and ``lcomp_simp`` until none of them can be applied anymore."""
# --> 148     spider_simp(g, quiet=quiet, stats=stats)
#     149     to_gh(g)
#     150     i = 0
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pyzx\simplify.py in spider_simp(g, matchf, quiet, stats)
#     120
#     121 def spider_simp(g: BaseGraph[VT,ET], matchf:Optional[Callable[[VT],bool]]=None, quiet:bool=False, stats:Optional[Stats]=None) -> int:
# --> 122     return simp(g, 'spider_simp', match_spider_parallel, spider, matchf=matchf, quiet=quiet, stats=stats)
#     123
#     124 def id_simp(g: BaseGraph[VT,ET], matchf:Optional[Callable[[VT],bool]]=None, quiet:bool=False, stats:Optional[Stats]=None) -> int:
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pyzx\simplify.py in simp(g, name, match, rewrite, matchf, quiet, stats)
#      96             g.remove_edges(rem_edges)
#      97             g.remove_vertices(rem_verts)
# ---> 98             if check_isolated_vertices: g.remove_isolated_vertices()
#      99             if not quiet: print('. ', end='')
#     100             #print('. ', end='', flush=True)
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pyzx\graph\base.py in remove_isolated_vertices(self)
#     829                 ty = self.type(v)
#     830                 if ty == VertexType.BOUNDARY:
# --> 831                     raise TypeError("Diagram is not a well-typed ZX-diagram: contains isolated boundary vertex.")
#     832                 elif ty == VertexType.H_BOX:
#     833                     self.scalar.add_phase(self.phase(v))
#
# TypeError: Diagram is not a well-typed ZX-diagram: contains isolated boundary vertex.

# %%
graph = teleportation_circuit.copy()
graphs = [zx.draw_matplotlib(graph)]
names = ["start"]
for gs, n in clifford_iter(graph):
    graphs.append(zx.draw_matplotlib(gs))
    names.append(n)
zx.drawing.pack_circuit_nf(gs,'grg')
graphs.append(zx.draw_matplotlib(gs))
names.append("reposition")

def plotter(rewrite):
    display(Markdown("Rewrite step: " + names[rewrite]))
    display(graphs[rewrite])

w = widgets.interactive(plotter, rewrite=(0,len(graphs)-1))
slider = w.children[0]
slider.layout.width = "{!s}px".format(min(800,50*len(graphs)))
output = w.children[-1]
output.layout.height = "{!s}px".format(204*20)
slider.value = 0
w
# Out:
# interactive(children=(IntSlider(value=0, description='rewrite', layout=Layout(width='500px'), max=9), Output(l…
